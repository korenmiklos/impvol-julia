# %%
using CSV
Pkg.add("LatexStrings")
# Out:
# INFO: Package LatexStrings is already installed
# INFO: METADATA is out-of-date — you may not have the latest version of LatexStrings
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
sigma05 = CSV.read("experiments/CES05/output_table.csv")
sigma10 = CSV.read("experiments/baseline/output_table.csv")
sigma20 = CSV.read("experiments/CES2/output_table.csv")
# Out:
# 25×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names          │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼────────────────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ Australia              │ 0.000945521 │ 0.000932271 │ 0.000965412 │
# │ 2   │ Austria                │ 0.000407016 │ 0.000798109 │ 0.000899212 │
# │ 3   │ Belgium and Luxembourg │ 0.00158767  │ 0.0025315   │ 0.00100395  │
# │ 4   │ Canada                 │ 0.000905012 │ 0.00186156  │ 0.00205532  │
# │ 5   │ China                  │ 0.0063165   │ 0.00630364  │ 0.00448538  │
# │ 6   │ Colombia               │ 0.00107343  │ 0.00121638  │ 0.00136407  │
# │ 7   │ Denmark                │ 0.000961156 │ 0.00208116  │ 0.00145753  │
# │ 8   │ Finland                │ 0.000658232 │ 0.000949259 │ 0.00120176  │
# │ 9   │ France                 │ 0.000216024 │ 0.000233282 │ 0.000268538 │
# │ 10  │ Germany                │ 0.000284062 │ 0.000420111 │ 0.000344451 │
# │ 11  │ Greece                 │ 0.000220581 │ 0.000206528 │ 0.000987046 │
# │ 12  │ India                  │ 0.000942249 │ 0.000949318 │ 0.00074503  │
# │ 13  │ Ireland                │ 0.00136554  │ 0.00369142  │ 0.00380299  │
# │ 14  │ Italy                  │ 0.000175802 │ 0.000185071 │ 0.000409331 │
# │ 15  │ Japan                  │ 0.0002949   │ 0.000290971 │ 0.000663982 │
# │ 16  │ Mexico                 │ 0.00108285  │ 0.00157079  │ 0.004388    │
# │ 17  │ Netherlands            │ 0.000542451 │ 0.0010734   │ 0.000981055 │
# │ 18  │ Norway                 │ 0.00180846  │ 0.00337062  │ 0.00497108  │
# │ 19  │ Portugal               │ 0.00177641  │ 0.00167903  │ 0.00222828  │
# │ 20  │ ROW                    │ 0.00167043  │ 0.00170383  │ 0.00134058  │
# │ 21  │ South Korea            │ 0.000816872 │ 0.000826968 │ 0.00164148  │
# │ 22  │ Spain                  │ 0.000207392 │ 0.000302301 │ 0.000714754 │
# │ 23  │ Sweden                 │ 0.000359137 │ 0.000537537 │ 0.000341399 │
# │ 24  │ United Kingdom         │ 0.000220176 │ 0.000306018 │ 0.000331398 │
# │ 25  │ United States          │ 0.000336305 │ 0.000334035 │ 0.000383312 │

# %%
diversification = [sigma05[:diversification] sigma10[:diversification] sigma20[:diversification]]
# Out:
# 25×3 Array{Float64,2}:
#      0.804434    -2.41104     -1.67714
#    -37.9236     -59.3693     -65.2042
#   -119.031     -114.056     -101.489
#    -87.9537     -86.3795     -84.7145
#     -1.69532      0.462775     0.532716
#    -95.2767     -31.337       -4.65445
#    -28.366      -44.838      -75.5897
#    -36.7831     -60.2945     -84.0769
#      5.61999      4.5402      -3.19498
#    -21.2711     -28.8466     -34.2176
#     24.0185      -7.85051    -54.9333
#    -28.4383     -11.4641      -6.108
#    -33.6558     -58.6117     -60.2583
#     22.6603       4.41629     -9.98061
#     11.973       -0.183948     4.23347
#    -81.5213     -95.2234     -69.9934
#   -147.023     -140.148     -122.973
#    -72.6627     -77.6919     -60.5397
#    -15.5757     -32.2292     -30.2034
#     -3.62019     -1.5662      -0.368507
#  -3017.44       -16.9018      -8.47795
#    -34.1248     -25.5735     -16.0989
#    -22.9116     -37.6506     -56.7564
#    -22.0886     -27.5346     -31.043
#      3.4311       1.50006      0.431792

# %%
specialization = [sigma05[:specialization] sigma10[:specialization] sigma20[:specialization]]
# Out:
# 25×3 Array{Float64,2}:
#    -3.32202    4.03952     3.09842
#     2.61922   19.2319     16.2017
#    65.8553    62.1197     64.206
#    26.4818    25.9617     33.3302
#     3.76002    0.531224   -0.328695
#    64.7794     9.74273    -7.09709
#   -43.3364   -21.3692     21.7735
#    15.283     32.9158     53.4186
#   -22.7322   -21.2066     -4.20287
#    -4.27097    0.540033    1.83358
#   -42.9696     1.68569    61.738
#    -1.01636    0.734404    5.36337
#   -19.9545    -3.55097    -2.74945
#   -37.3111   -19.0735      4.97218
#   -11.429      0.326163   -2.88317
#    13.8475    43.6993     38.9301
#    99.252     91.7881     73.5092
#    38.8538    43.377      14.1934
#    10.1575    36.3272     36.003
#     4.86186    1.35899    -1.59137
#  3022.32      10.7733      7.25706
#   -28.7576   -28.6613    -15.2966
#    -6.2592     3.40381    23.568
#   -25.0627   -15.9918      2.99189
#    -4.19348   -2.27615     0.24795

# %%
overall = [sigma05[:trade_barriers] sigma10[:trade_barriers] sigma20[:trade_barriers]]
# Out:
# 25×3 Array{Float64,2}:
#   -2.51759     1.62848     1.42128
#  -35.3044    -40.1374    -49.0024
#  -53.1758    -51.9366    -37.2834
#  -61.4719    -60.4178    -51.3843
#    2.06471     0.993999    0.20402
#  -30.4973    -21.5942    -11.7515
#  -71.7024    -66.2071    -53.8162
#  -21.5001    -27.3787    -30.6583
#  -17.1122    -16.6664     -7.39785
#  -25.542     -28.3066    -32.384
#  -18.9511     -6.16481     6.8047
#  -29.4547    -10.7297     -0.744626
#  -53.6103    -62.1627    -63.0078
#  -14.6508    -14.6572     -5.00842
#    0.543979    0.142215    1.3503
#  -67.6739    -51.5241    -31.0633
#  -47.7709    -48.3601    -49.4643
#  -33.8089    -34.3149    -46.3463
#   -5.41826     4.09803     5.7996
#    1.24168    -0.20721    -1.95988
#    4.88922    -6.12847    -1.22089
#  -62.8824    -54.2349    -31.3955
#  -29.1708    -34.2468    -33.1885
#  -47.1513    -43.5264    -28.0512
#   -0.762376   -0.776093    0.679742

# %%
using Plots

# %%
sorted = sortrows(overall, by = x -> x[2])
# Out:
# 25×3 Array{Float64,2}:
#  -71.7024    -66.2071    -53.8162
#  -53.6103    -62.1627    -63.0078
#  -61.4719    -60.4178    -51.3843
#  -62.8824    -54.2349    -31.3955
#  -53.1758    -51.9366    -37.2834
#  -67.6739    -51.5241    -31.0633
#  -47.7709    -48.3601    -49.4643
#  -47.1513    -43.5264    -28.0512
#  -35.3044    -40.1374    -49.0024
#  -33.8089    -34.3149    -46.3463
#  -29.1708    -34.2468    -33.1885
#  -25.542     -28.3066    -32.384
#  -21.5001    -27.3787    -30.6583
#  -30.4973    -21.5942    -11.7515
#  -17.1122    -16.6664     -7.39785
#  -14.6508    -14.6572     -5.00842
#  -29.4547    -10.7297     -0.744626
#  -18.9511     -6.16481     6.8047
#    4.88922    -6.12847    -1.22089
#   -0.762376   -0.776093    0.679742
#    1.24168    -0.20721    -1.95988
#    0.543979    0.142215    1.3503
#    2.06471     0.993999    0.20402
#   -2.51759     1.62848     1.42128
#   -5.41826     4.09803     5.7996

# %%
plot(sorted)

# %%
function in_between(data1, data2, data3, tolerance=0.0)
    # miniscule sign deviations do not count
    return (data1 .- data2) .* (data2 .- data3) .> -tolerance
end
function plot_sorted(data, tolerance)
    sorted = sortrows(data, by = x->x[2])
    r1 = length(sorted[:,1])
    r2 = length(sorted[:,1][in_between(sorted[:,1], sorted[:,2], sorted[:,3])])
    plot(sorted, label=["sigma=0.5", "sigma=1.0", "sigma=2.0"], xlabel="Countries sorted by Cobb-Douglas effect", ylabel="Percentage change in volatility", title="$r2/$r1 corrert orders")
end
# Out:
# plot_sorted (generic function with 2 methods)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(diversification[rows,:], 2.0)

# %%
plot_sorted(overall, 2.0)

# %%
level = [sigma05[:kappa1972] sigma10[:kappa1972] sigma20[:kappa1972]]
# Out:
# 25×3 Array{Float64,2}:
#  0.00119614   0.00101085   0.000932271
#  0.0010418    0.000749953  0.000798109
#  0.00227876   0.0019904    0.0025315
#  0.00190231   0.00146688   0.00186156
#  0.00617226   0.0062962    0.00630364
#  0.00180271   0.00149568   0.00121638
#  0.00253416   0.00180307   0.00208116
#  0.00121441   0.000966336  0.000949259
#  0.000528907  0.000361041  0.000233282
#  0.000652343  0.000477445  0.000420111
#  0.000682581  0.000346199  0.000206528
#  0.00201255   0.00124568   0.000949318
#  0.0033615    0.00293865   0.00369142
#  0.000518831  0.000322983  0.000185071
#  0.000479907  0.000356824  0.000290971
#  0.00392428   0.00220806   0.00157079
#  0.00108175   0.000835448  0.0010734
#  0.00144204   0.0014215    0.00337062
#  0.00165379   0.00147062   0.00167903
#  0.00184209   0.00176349   0.00170383
#  0.00291568   0.000964024  0.000826968
#  0.00128302   0.000691076  0.000302301
#  0.000836874  0.000628068  0.000537537
#  0.000758581  0.000516546  0.000306018
#  0.000450812  0.000353097  0.000334035

# %%
plot_sorted(level, 0.0001)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(specialization[rows,:], 2.0)

# %%
# explore outlier
sigma05[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual     │ kappa1972  │ nosectoral │
# ├─────┼───────────────┼────────────┼────────────┼────────────┤
# │ 1   │ South Korea   │ 0.00305823 │ 0.00291568 │ 4.50853    │

# %%
sigma10[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼───────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ South Korea   │ 0.000904944 │ 0.000964024 │ 0.000717621 │

# %%
# this looks like runtime fluke, rerun sigma=0.5

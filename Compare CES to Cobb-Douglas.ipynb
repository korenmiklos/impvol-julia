# %%
using CSV

# %%
sigma05 = CSV.read("experiments/CES05/output_table.csv")
sigma10 = CSV.read("experiments/baseline/output_table.csv")
sigma20 = CSV.read("experiments/CES2/output_table.csv")
# Out:
# 25×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names          │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼────────────────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ Australia              │ 0.000947693 │ 0.000931479 │ 0.000967457 │
# │ 2   │ Austria                │ 0.000382047 │ 0.000756121 │ 0.000895558 │
# │ 3   │ Belgium and Luxembourg │ 0.00163543  │ 0.00253251  │ 0.00100007  │
# │ 4   │ Canada                 │ 0.000899463 │ 0.0018492   │ 0.00204941  │
# │ 5   │ China                  │ 0.00634738  │ 0.00633074  │ 0.00448352  │
# │ 6   │ Colombia               │ 0.00108067  │ 0.00121882  │ 0.00136555  │
# │ 7   │ Denmark                │ 0.000986425 │ 0.00209321  │ 0.00145806  │
# │ 8   │ Finland                │ 0.000662468 │ 0.000947556 │ 0.0011943   │
# │ 9   │ France                 │ 0.000215804 │ 0.000233089 │ 0.000268802 │
# │ 10  │ Germany                │ 0.000287706 │ 0.000420909 │ 0.000344725 │
# │ 11  │ Greece                 │ 0.000221479 │ 0.000206765 │ 0.000988879 │
# │ 12  │ India                  │ 0.000941509 │ 0.00094605  │ 0.000743991 │
# │ 13  │ Ireland                │ 0.00140572  │ 0.00360325  │ 0.00379279  │
# │ 14  │ Italy                  │ 0.000175095 │ 0.00018415  │ 0.0004093   │
# │ 15  │ Japan                  │ 0.0002959   │ 0.000291105 │ 0.000663804 │
# │ 16  │ Mexico                 │ 0.00107449  │ 0.0015534   │ 0.00437562  │
# │ 17  │ Netherlands            │ 0.000536627 │ 0.00107219  │ 0.00098149  │
# │ 18  │ Norway                 │ 0.00191215  │ 0.00337796  │ 0.00496181  │
# │ 19  │ Portugal               │ 0.00178681  │ 0.00169338  │ 0.00221928  │
# │ 20  │ ROW                    │ 0.00167426  │ 0.00171067  │ 0.00133953  │
# │ 21  │ South Korea            │ 0.000816287 │ 0.00082488  │ 0.00164043  │
# │ 22  │ Spain                  │ 0.000206447 │ 0.00030169  │ 0.000714261 │
# │ 23  │ Sweden                 │ 0.000358339 │ 0.000536732 │ 0.000337788 │
# │ 24  │ United Kingdom         │ 0.000220017 │ 0.00030524  │ 0.000330836 │
# │ 25  │ United States          │ 0.000337473 │ 0.000335123 │ 0.000384091 │

# %%
diversification = [sigma05[:diversification] sigma10[:diversification] sigma20[:diversification]]
# Out:
# 25×3 Array{Float64,2}:
#      1.60088    -2.71727    -1.57631
#    -45.162     -62.6942    -69.2918
#   -119.725    -114.618    -101.366
#    -89.851     -86.9015    -85.4223
#     -1.3213      0.38961     0.496241
#    -99.2228    -31.8827     -4.81076
#    -23.2856    -46.8665    -74.3158
#    -37.7064    -61.0013    -84.9072
#      8.73538     5.70819    -3.11132
#    -21.2425    -28.2608    -34.141
#     30.9992     -8.16287   -55.0217
#    -26.43      -10.1406     -6.04048
#    -26.2763    -65.238     -62.3111
#     17.8877      3.93312   -10.1352
#      4.01542     2.00127     4.0669
#    -83.0992    -95.1224    -71.0108
#   -152.342    -138.285    -122.881
#    -76.6227    -77.9728    -60.387
#    -27.6826    -36.0335    -30.3262
#     -3.26332    -2.57211    -0.361564
#  -3586.85      -18.8829     -8.72523
#    -36.5131    -26.0722    -16.3814
#    -19.0147    -38.1071    -57.553
#    -22.6346    -27.7369    -31.1628
#     12.7319      2.27753     0.512122

# %%
specialization = [sigma05[:specialization] sigma10[:specialization] sigma20[:specialization]]
# Out:
# 25×3 Array{Float64,2}:
#    -3.93917    4.45117     3.31708
#     6.96761   23.0064     19.819
#    65.6844    64.0987     65.9434
#    28.3497    26.7764     34.0631
#     3.05599    1.10426    -0.233411
#    71.4486    10.6032     -6.52405
#   -46.7585   -17.1422     21.4408
#    15.7439    36.1024     54.8205
#   -26.1495   -21.779      -4.30431
#    -4.13168    0.483905    2.49443
#   -51.3563     1.27215    62.1379
#    -3.24135   -1.0424      5.56046
#   -26.7316     4.99156     1.32353
#   -32.7282   -18.6993      5.21781
#    -3.74196   -2.82541    -2.41986
#    16.6487    43.1875     40.1808
#   107.289     91.9373     72.9308
#    47.2987    47.407      16.9937
#    13.7416    39.668      35.8436
#     5.28008    3.19576    -1.76735
#  3583.19      10.483       7.6834
#   -26.4894   -28.4217    -15.1886
#   -11.6153     3.19982    24.3162
#   -24.4721   -16.0223      3.24284
#   -13.949     -2.73424     0.189146

# %%
overall = [sigma05[:trade_barriers] sigma10[:trade_barriers] sigma20[:trade_barriers]]
# Out:
# 25×3 Array{Float64,2}:
#   -2.33829     1.73391     1.74077
#  -38.1944    -39.6878    -49.4728
#  -54.041     -50.5198    -35.4223
#  -61.5013    -60.1251    -51.3592
#    1.7347      1.49387     0.26283
#  -27.7742    -21.2795    -11.3348
#  -70.0441    -64.0087    -52.875
#  -21.9624    -24.8989    -30.0867
#  -17.4141    -16.0709     -7.41563
#  -25.3742    -27.7769    -31.6466
#  -20.3571     -6.89072     7.11624
#  -29.6713    -11.183      -0.480018
#  -53.0079    -60.2465    -60.9875
#  -14.8406    -14.7662     -4.91736
#    0.273464   -0.824138    1.64705
#  -66.4505    -51.9349    -30.8299
#  -45.0536    -46.3474    -49.9503
#  -29.3241    -30.5658    -43.3933
#  -13.941       3.63451     5.51736
#    2.01676     0.623654   -2.12891
#   -3.66272    -8.39992    -1.04183
#  -63.0025    -54.4939    -31.57
#  -30.6299    -34.9073    -33.2369
#  -47.1067    -43.7592    -27.92
#   -1.21709    -0.456716    0.701268

# %%
using Plots

# %%
function in_between(data1, data2, data3, tolerance=0.0)
    # miniscule sign deviations do not count
    return (data1 .- data2) .* (data2 .- data3) .> -tolerance
end
function plot_sorted(data, tolerance)
    sorted = sortrows(data, by = x->x[2])
    r1 = length(sorted[:,1])
    r2 = length(sorted[:,1][in_between(sorted[:,1], sorted[:,2], sorted[:,3])])
    plot(sorted, label=["sigma=0.5", "sigma=1.0", "sigma=2.0"], xlabel="Countries sorted by Cobb-Douglas effect", ylabel="Percentage change in volatility", title="$r2/$r1 corrert orders")
end
# Out:
# plot_sorted (generic function with 1 method)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(diversification[rows,:], 2.0)

# %%
plot_sorted(overall, 2.0)

# %%
level = [sigma05[:kappa1972] sigma10[:kappa1972] sigma20[:kappa1972]]
# Out:
# 25×3 Array{Float64,2}:
#  0.0011497    0.00101126   0.000931479
#  0.00100661   0.000716237  0.000756121
#  0.00228475   0.00198373   0.00253251
#  0.00187447   0.00145703   0.0018492
#  0.00623163   0.0063092    0.00633074
#  0.00180969   0.00148642   0.00121882
#  0.00236529   0.00173613   0.00209321
#  0.00122607   0.000968536  0.000947556
#  0.000533779  0.000360796  0.000233089
#  0.000646919  0.000476692  0.000420909
#  0.000691466  0.000352451  0.000206765
#  0.00202215   0.00124749   0.00094605
#  0.00354694   0.00286229   0.00360325
#  0.0005069    0.000325791  0.00018415
#  0.00048147   0.000361485  0.000291105
#  0.00393797   0.002192     0.0015534
#  0.0010261    0.000829921  0.00107219
#  0.00135421   0.00141272   0.00337796
#  0.00178806   0.00148589   0.00169338
#  0.00185081   0.00175525   0.00171067
#  0.00252843   0.000979358  0.00082488
#  0.00128572   0.000692532  0.00030169
#  0.000820707  0.000628749  0.000536732
#  0.000760235  0.000520332  0.00030524
#  0.000457846  0.000353036  0.000335123

# %%
plot_sorted(level, 0.0001)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(specialization[rows,:], 2.0)

# %%
# explore outlier
sigma05[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual     │ kappa1972  │ nosectoral │
# ├─────┼───────────────┼────────────┼────────────┼────────────┤
# │ 1   │ South Korea   │ 0.00243582 │ 0.00252843 │ 4.50638    │

# %%
sigma10[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼───────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ South Korea   │ 0.000897092 │ 0.000979358 │ 0.000700766 │

# %%
# this looks like runtime fluke, rerun sigma=0.5

# %%
# Korea is still wrong, will have to explore further

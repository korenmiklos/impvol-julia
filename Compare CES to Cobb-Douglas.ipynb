# %%
using CSV

# %%
sigma05 = CSV.read("experiments/CES05/output_table.csv")
sigma10 = CSV.read("experiments/baseline/output_table.csv")
sigma20 = CSV.read("experiments/CES2/output_table.csv")
# Out:
# 25×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names          │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼────────────────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ Australia              │ 0.000944123 │ 0.000931892 │ 0.000965638 │
# │ 2   │ Austria                │ 0.00038326  │ 0.000764769 │ 0.000899194 │
# │ 3   │ Belgium and Luxembourg │ 0.00162051  │ 0.00254181  │ 0.00100389  │
# │ 4   │ Canada                 │ 0.000898192 │ 0.00184915  │ 0.00205522  │
# │ 5   │ China                  │ 0.00632443  │ 0.00630301  │ 0.00448657  │
# │ 6   │ Colombia               │ 0.00107315  │ 0.00121357  │ 0.00136435  │
# │ 7   │ Denmark                │ 0.000978568 │ 0.00207787  │ 0.00145755  │
# │ 8   │ Finland                │ 0.000664599 │ 0.000949068 │ 0.00120163  │
# │ 9   │ France                 │ 0.000215742 │ 0.000233019 │ 0.00026857  │
# │ 10  │ Germany                │ 0.000286417 │ 0.000422039 │ 0.000344482 │
# │ 11  │ Greece                 │ 0.000220977 │ 0.000207204 │ 0.000987356 │
# │ 12  │ India                  │ 0.000943455 │ 0.000949114 │ 0.000745001 │
# │ 13  │ Ireland                │ 0.00139487  │ 0.00365874  │ 0.00380267  │
# │ 14  │ Italy                  │ 0.000175846 │ 0.000185083 │ 0.000409294 │
# │ 15  │ Japan                  │ 0.000294586 │ 0.000290918 │ 0.000663871 │
# │ 16  │ Mexico                 │ 0.00108289  │ 0.00156416  │ 0.00438802  │
# │ 17  │ Netherlands            │ 0.000534227 │ 0.00106749  │ 0.000981319 │
# │ 18  │ Norway                 │ 0.00188026  │ 0.00336357  │ 0.00497283  │
# │ 19  │ Portugal               │ 0.00178642  │ 0.00168241  │ 0.00222888  │
# │ 20  │ ROW                    │ 0.00167295  │ 0.0017042   │ 0.00134046  │
# │ 21  │ South Korea            │ 0.000817115 │ 0.000827137 │ 0.00164254  │
# │ 22  │ Spain                  │ 0.000207759 │ 0.000302431 │ 0.000714723 │
# │ 23  │ Sweden                 │ 0.000359903 │ 0.0005375   │ 0.000341331 │
# │ 24  │ United Kingdom         │ 0.000219736 │ 0.000306232 │ 0.00033138  │
# │ 25  │ United States          │ 0.000335868 │ 0.000334105 │ 0.000383265 │

# %%
diversification = [sigma05[:diversification] sigma10[:diversification] sigma20[:diversification]]
# Out:
# 25×3 Array{Float64,2}:
#      2.35001    -2.63562     -1.65711
#    -40.358     -62.2004     -67.8888
#   -120.287    -112.797     -101.082
#    -90.2046    -86.7134     -85.2809
#     -1.26751     0.484211     0.553203
#    -98.8282    -32.0415      -4.65265
#    -27.8643    -45.4591     -75.6721
#    -36.1115    -60.1252     -84.1187
#      6.14686     4.54134     -3.19899
#    -21.9662    -28.8363     -34.0602
#     27.0328     -7.55182    -54.6249
#    -26.43      -11.3324      -6.12519
#    -32.9327    -59.3169     -60.8437
#     25.0869      4.40942    -10.0242
#     11.2537     -0.109186     4.19074
#    -84.0016    -94.7641     -70.3031
#   -151.888    -140.551     -123.636
#    -76.8755    -77.8194     -60.6169
#    -24.8006    -32.2477     -30.118
#     -3.99916    -1.71586     -0.372486
#  -3415.85      -16.8612      -8.34148
#    -34.7268    -25.5404     -16.1266
#    -22.9401    -37.5396     -56.7741
#    -21.9046    -27.4021     -31.0205
#      4.14198     1.41557      0.415656

# %%
specialization = [sigma05[:specialization] sigma10[:specialization] sigma20[:specialization]]
# Out:
# 25×3 Array{Float64,2}:
#    -5.01332    4.00563     2.96966
#     1.39212   22.0479     18.0033
#    67.4707    59.5721     64.8363
#    28.4512    26.1415     33.8542
#     3.22651    0.890862   -0.213344
#    71.2226    10.5181     -6.9184
#   -44.1394   -20.0327     22.7668
#    14.3776    35.0063     54.1452
#   -24.4115   -21.3286     -4.21529
#    -3.80174    0.446818    1.92538
#   -46.1225     1.51639    61.272
#    -3.42295    0.687611    5.52893
#   -18.6202    -0.985048   -1.03206
#   -40.2631   -19.1085      5.0334
#   -12.1778    -0.207414   -2.92982
#    17.2298    43.345      39.5348
#   106.294     92.0817     73.6812
#    48.7386    44.3682     16.5175
#    10.6039    36.7694     36.3001
#     6.19297    1.63074    -1.46145
#  3423.5       10.3503      7.12993
#   -28.231    -28.6454    -15.1771
#    -8.22019    3.55954    23.7328
#   -25.9263   -16.4477      2.77527
#    -6.08547   -2.39653     0.112035

# %%
overall = [sigma05[:trade_barriers] sigma10[:trade_barriers] sigma20[:trade_barriers]]
# Out:
# 25×3 Array{Float64,2}:
#   -2.66331    1.37001      1.31255
#  -38.9659   -40.1524     -49.8856
#  -52.8167   -53.2248     -36.2458
#  -61.7533   -60.5719     -51.4268
#    1.959      1.37507      0.339858
#  -27.6055   -21.5234     -11.571
#  -72.0037   -65.4918     -52.9052
#  -21.7339   -25.119      -29.9735
#  -18.2646   -16.7872      -7.41428
#  -25.768    -28.3894     -32.1348
#  -19.0896    -6.03543      6.64709
#  -29.853    -10.6447      -0.596263
#  -51.553    -60.3019     -61.8758
#  -15.1761   -14.6991      -4.99083
#   -0.92408   -0.316599     1.26093
#  -66.7717   -51.4191     -30.7684
#  -45.5942   -48.4689     -49.9549
#  -28.1369   -33.4512     -44.0993
#  -14.1967     4.52174      6.18208
#    2.19381   -0.0851218   -1.83394
#    7.65359   -6.51088     -1.21155
#  -62.9578   -54.1858     -31.3037
#  -31.1603   -33.9801     -33.0414
#  -47.8309   -43.8499     -28.2453
#   -1.94349   -0.980961     0.527691

# %%
using Plots

# %%
sorted = sortrows(overall, by = x -> x[2])
# Out:
# 25×3 Array{Float64,2}:
#  -71.7024    -66.2071    -53.8162
#  -53.6103    -62.1627    -63.0078
#  -61.4719    -60.4178    -51.3843
#  -62.8824    -54.2349    -31.3955
#  -53.1758    -51.9366    -37.2834
#  -67.6739    -51.5241    -31.0633
#  -47.7709    -48.3601    -49.4643
#  -47.1513    -43.5264    -28.0512
#  -35.3044    -40.1374    -49.0024
#  -33.8089    -34.3149    -46.3463
#  -29.1708    -34.2468    -33.1885
#  -25.542     -28.3066    -32.384
#  -21.5001    -27.3787    -30.6583
#  -30.4973    -21.5942    -11.7515
#  -17.1122    -16.6664     -7.39785
#  -14.6508    -14.6572     -5.00842
#  -29.4547    -10.7297     -0.744626
#  -18.9511     -6.16481     6.8047
#    4.88922    -6.12847    -1.22089
#   -0.762376   -0.776093    0.679742
#    1.24168    -0.20721    -1.95988
#    0.543979    0.142215    1.3503
#    2.06471     0.993999    0.20402
#   -2.51759     1.62848     1.42128
#   -5.41826     4.09803     5.7996

# %%
plot(sorted)

# %%
function in_between(data1, data2, data3, tolerance=0.0)
    # miniscule sign deviations do not count
    return (data1 .- data2) .* (data2 .- data3) .> -tolerance
end
function plot_sorted(data, tolerance)
    sorted = sortrows(data, by = x->x[2])
    r1 = length(sorted[:,1])
    r2 = length(sorted[:,1][in_between(sorted[:,1], sorted[:,2], sorted[:,3])])
    plot(sorted, label=["sigma=0.5", "sigma=1.0", "sigma=2.0"], xlabel="Countries sorted by Cobb-Douglas effect", ylabel="Percentage change in volatility", title="$r2/$r1 corrert orders")
end
# Out:
# plot_sorted (generic function with 1 method)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(diversification[rows,:], 2.0)

# %%
plot_sorted(overall, 2.0)

# %%
level = [sigma05[:kappa1972] sigma10[:kappa1972] sigma20[:kappa1972]]
# Out:
# 25×3 Array{Float64,2}:
#  0.0011507    0.00101167   0.000931892
#  0.00101386   0.000717417  0.000764769
#  0.00227654   0.00201603   0.00254181
#  0.00186535   0.00146098   0.00184915
#  0.00623178   0.00629721   0.00630301
#  0.00178709   0.00148907   0.00121357
#  0.00243001   0.00178874   0.00207787
#  0.00122191   0.000969037  0.000949068
#  0.000533554  0.000361344  0.000233019
#  0.00064852   0.000478399  0.000422039
#  0.00067367   0.000347038  0.000207204
#  0.00199946   0.00124339   0.000949114
#  0.00347831   0.00290583   0.00365874
#  0.000504983  0.000322884  0.000185083
#  0.000477555  0.000358319  0.000290918
#  0.00391641   0.00220142   0.00156416
#  0.00102363   0.000832272  0.00106749
#  0.00135371   0.00141851   0.00336357
#  0.00177399   0.00147433   0.00168241
#  0.00185636   0.00176385   0.0017042
#  0.00255611   0.000964577  0.000827137
#  0.00127608   0.000692017  0.000302431
#  0.000827918  0.00062943   0.0005375
#  0.000756921  0.000517994  0.000306232
#  0.000455112  0.00035355   0.000334105

# %%
plot_sorted(level, 0.0001)

# %%
# there is something wrong in country 21, needs to be fixed
rows = [1:20; 22:25]
plot_sorted(specialization[rows,:], 2.0)

# %%
# explore outlier
sigma05[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual     │ kappa1972  │ nosectoral │
# ├─────┼───────────────┼────────────┼────────────┼────────────┤
# │ 1   │ South Korea   │ 0.00275174 │ 0.00255611 │ 4.50816    │

# %%
sigma10[21,:]
# Out:
# 1×8 DataFrames.DataFrame. Omitted printing of 4 columns
# │ Row │ country_names │ actual      │ kappa1972   │ nosectoral  │
# ├─────┼───────────────┼─────────────┼─────────────┼─────────────┤
# │ 1   │ South Korea   │ 0.000901774 │ 0.000964577 │ 0.000717339 │

# %%
# this looks like runtime fluke, rerun sigma=0.5

# %%
# Korea is still wrong, will have to explore further
